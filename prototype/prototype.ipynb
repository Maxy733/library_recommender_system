# %%
import pandas as pd
import gspread
import smtplib
from email.message   import EmailMessage
from oauth2client.service_account import ServiceAccountCredentials
import os

# %%
# Load mock user input
users_df = pd.read_csv("user_data.csv")
users_df.head()
# Load book metadata
books_df = pd.read_csv("books_metadata.csv")
books_df.head()
# Out:
#                     Title          Author        Genre Format  \
# 0            The Stranger    Albert Camus  Non-fiction  Ebook
# 1              The Hobbit  J.R.R. Tolkien    Dystopian  Ebook
# 2  The Catcher in the Rye   J.D. Salinger      Fiction  Ebook
# 3   To Kill a Mockingbird      Harper Lee      Classic  Ebook
# 4                    1984   George Orwell      Science  Ebook
#
#                ISBN
# 0  978-6-467-9299-8
# 1  978-0-325-2247-6
# 2  978-4-659-9582-6
# 3  978-3-442-4796-9
# 4  978-2-439-7141-7

# %%
# # Google Sheets authentication
# scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
# creds = ServiceAccountCredentials.from_json_keyfile_name("credentials.json", scope)
# client = gspread.authorize(creds)
#
# # Get the sheet
# sheet = client.open("Form Responses 1").sheet1
# data = sheet.get_all_records()
# user_df = pd.DataFrame(data)
# user_df.head()

# %%
def recommend_books(user_row, book_db):
    genre = user_row['genres']
    format_pref = user_row['book_format']

    matches = book_db[
        (book_db['Genre'].str.lower().str.contains(genre.lower(), na=False)) |  # Changed & to | for more matches
        (book_db['Format'].str.lower().str.contains(format_pref.lower(), na=False))

    ]
    if len(matches) == 0:
        return book_db.head(3)  # Return first 3 books as fallback

    return matches.head(5)

# Create output folder
os.makedirs("output_recommendations", exist_ok=True)

# Loop through each user
for i, user in users_df.iterrows():
    recs = recommend_books(user, books_df)

    # Add some debug printing
    print(f"Found {len(recs)} recommendations for {user['full_name']}")

    with open(f"output_recommendations/{user['full_name']}_recs.txt", "w") as f:
        f.write(f"Dear {user['full_name']},\n\n")
        f.write("Here are your personalized book recommendations:\n\n")
        if len(recs) > 0:
            for _, book in recs.iterrows():
                f.write(f"• {book['Title']} by {book['Author']} ({book['Genre']})\n")
        else:
            f.write("Sorry, no specific recommendations found based on your preferences.\n")
# Out:
# Found 5 recommendations for Abigael Romanin
# Found 5 recommendations for Tedda Dhennin
# Found 3 recommendations for Kent Corneck
# Found 3 recommendations for Matthieu Dignam
# Found 3 recommendations for Patty Rakestraw
# Found 5 recommendations for Beau Bourhill
# Found 5 recommendations for Carmelita Butland
# Found 5 recommendations for Juliana Manion
# Found 5 recommendations for Ignace Joburn
# Found 5 recommendations for Rex Cradick
# Found 3 recommendations for Celia McKellar
# Found 5 recommendations for Baxy Langstone
# Found 5 recommendations for Karel Robardley
# Found 5 recommendations for Lottie Minton
# Found 5 recommendations for Karlik Lainton
# Found 3 recommendations for Tudor Garard
# Found 5 recommendations for Blancha Moscone
# Found 5 recommendations for Hilton Mushet
# Found 5 recommendations for Sam Swinburne
# Found 3 recommendations for Heddi Ribbon
# Found 3 recommendations for Carlie Ferroli
# Found 3 recommendations for Frasquito Woodrough
# Found 3 recommendations for Madella Hannay
# Found 5 recommendations for Anna Draayer
# Found 3 recommendations for Cecilla Killen
# Found 5 recommendations for Benedetto Brazenor
# Found 5 recommendations for Barnie Renn
# Found 3 recommendations for Daniela Blasing
# Found 3 recommendations for Lena Penni
# Found 3 recommendations for Marijn Sitford
# Found 3 recommendations for Rozalin Topes
# Found 3 recommendations for Lockwood Tocqueville
# Found 3 recommendations for Alaster Huyghe
# Found 5 recommendations for Marja Isakowicz
# Found 3 recommendations for Shani Curbishley
# Found 3 recommendations for Tricia Cawkill
# Found 3 recommendations for Rori Underwood
# Found 5 recommendations for Felecia Stuchberry
# Found 3 recommendations for Magda Surgeon
# Found 3 recommendations for Sol McGrey
# Found 5 recommendations for Scottie Vasile
# Found 3 recommendations for Cassius Cheverell
# Found 3 recommendations for Elisabetta Jamblin
# Found 3 recommendations for Ferdy Lob
# Found 5 recommendations for Terry Torfin
# Found 5 recommendations for Flinn Danilenko
# Found 3 recommendations for Obadias Scrivinor
# Found 3 recommendations for Cristal Burg
# Found 3 recommendations for Gelya Havile
# Found 5 recommendations for Missy Nitti
# Found 5 recommendations for Grantham Simla
# Found 3 recommendations for Vonnie Spick
# Found 3 recommendations for Calla Cray
# Found 5 recommendations for Lynda Jacques
# Found 3 recommendations for Sammy Smeath
# Found 5 recommendations for Sherilyn Shelbourne
# Found 3 recommendations for Elly Gumary
# Found 3 recommendations for Elliott Taveriner
# Found 3 recommendations for Elmer Shwalbe
# Found 3 recommendations for Vassili Selway
# Found 3 recommendations for Falkner Wynter
# Found 5 recommendations for Alan O'Corrin
# Found 3 recommendations for Justus Stuart
# Found 3 recommendations for Miguelita Rance
# Found 5 recommendations for Jody Runge
# Found 5 recommendations for Shani Thiolier
# Found 5 recommendations for Erinna Lawrey
# Found 3 recommendations for Quintin Samweyes
# Found 3 recommendations for Fields Atling
# Found 3 recommendations for Shayne Salamon
# Found 5 recommendations for Claudina Wookey
# Found 3 recommendations for Janel Jossum
# Found 5 recommendations for Xenos Bodocs
# Found 3 recommendations for Aeriell Sheara
# Found 3 recommendations for Arlen Hogbin
# Found 5 recommendations for Jillie Plane
# Found 3 recommendations for Angel Eberts
# Found 3 recommendations for Wallas Taynton
# Found 3 recommendations for Joceline Boak
# Found 3 recommendations for Stormie Arkwright
# Found 5 recommendations for Ardine Conner
# Found 3 recommendations for Silvain Zanni
# Found 3 recommendations for Queenie Maplethorp
# Found 3 recommendations for Lezley Costley
# Found 5 recommendations for Steven Goldson
# Found 3 recommendations for Madison Halladay
# Found 5 recommendations for Vick Tiptaft
# Found 3 recommendations for Odele Colisbe
# Found 3 recommendations for Lorita Antonnikov
# Found 5 recommendations for Caresa Thiem
# Found 5 recommendations for Sawyere Drogan
# Found 5 recommendations for Lorie Ewens
# Found 3 recommendations for Lemar Gravell
# Found 3 recommendations for Thom Blumson
# Found 3 recommendations for Caryn Chritchley
# Found 3 recommendations for Allison Bielfeldt
# Found 3 recommendations for Lotte Trowsdale
# Found 5 recommendations for Daryl Ingraham
# Found 3 recommendations for Vanda Grzesiak
# Found 5 recommendations for Lazar Nicklinson
